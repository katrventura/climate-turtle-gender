# %% [markdown]
# # Sea Turtle Nesting and Rising Ocean Temperatures 𓆉
#
# Exploring datasets on sea turtle nesting locations, sea surface temperature, and endangered sea turtle species.

# %% [markdown]
# ## About the project

# %% [markdown]
# During the winter break I went back to the Philippines and drove to a town called Bagac in the province of Bataan where volunteers of the Pag-asa Pawikan Protection and Conservation Center look after nests of hawksbill sea turtles and release baby sea turtles in the beach once they have hatched. Hawksbills are considered critically endangered species because their eggs have been vulnerable to poachers, predators, and climate change. I went to the center in time for hatching season November to February and released a baby sea turtles in the ocean which I named, "Malaya" (meaning Freedom).
#
# This project is for Malaya. My goal is to create a map of the turtle nesting sites in the world with data showing the rising ocean temperatures in the different hemispheres. More research has been released showing the effects of warmer sand to the sea turtle eggs. Among the consequences of rising temperature is that it produces more female hatchlings. https://www.nationalgeographic.com/science/article/australia-green-sea-turtles-turning-female-climate-change-raine-island-sex-temperature
#
# Backup plan: Rising ocean temperatures are just among the external factors affecting sea turtle nesting and hatching and so if I am unable to produce a map with the datasets that I have, I can produce a graphic story of the other factors affecting turtle nesting and hatching using datawrapper.

# %% [markdown]
# ## Datasets

# %% [markdown]
# * The State of the Worlds Sea Turtles - This is the main database on sea turtle nesting in which information about sea turtle nesting activities has been provided by more than 600 different contributors from 130 countries. Request for Nesting Site Locations in csv format and Shapefile have been made.
#
# Nesting Site Locations (csv)
# Request ID: 65b5cb597f9f8_20240128_144740
# Requested: 2024-01-28 14:47:40
#
# Nesting Site Locations (Shapefile)
# Request ID: 65b5cb597f9f8_20240128_151459
# Requested: 2024-01-28 15:14:59

# %% [markdown]
# * Backup files! If the State of the Worlds Sea Turtles does not get back to me on my request, a csv of their data has been cited by a research on turtle fecundity and made public on Github Sea turtle reproductive energy https://github.com/nicholaswunz/turtle-fecundity || Filename: nesting-sites, turtle-species

# %% [markdown]
# * NASA Ocean Warming Annual Data (1957-2020) https://www.nasa.gov/stem-content/annual-ocean-warming-data-set/ || Filename: ocean-warming

# %% [markdown]
# * Ocean Data Viewer - Mean Annual Sea Surface Temperature (2009-2013)
# https://data.unep-wcmc.org/datasets/36  / Github - Ocean Data Viewer https://github.com/unepwcmc/ocean-data-viewer || Folder: map-sea-temp

# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Sea Turtle Species

# %%
turtles = pd.read_csv('turtle-species.csv', encoding='latin-1')
turtles
# Out:
#      Unnamed: 0                 name                species  protected_perc  \
# 0            16            Australia        Caretta_caretta        56.25000
# 1            33               Brazil        Caretta_caretta        50.00000
# 2            48             Colombia        Caretta_caretta        46.97000
# 3            50           Cape Verde        Caretta_caretta         0.00000
# 4            51           Costa Rica        Caretta_caretta       100.00000
# ..          ...                  ...                    ...             ...
# 339         219  Trinidad and Tobago  Lepidochelys_olivacea         0.00000
# 340         234              Vietnam  Lepidochelys_olivacea        42.86000
# 341         235              Vanuatu  Lepidochelys_olivacea         0.00000
# 342         247        French Guiana  Lepidochelys_olivacea        33.33000
# 343          16            Australia      Natator_depressus        72.06471
#
#      mean_temp  mean_mass    mass_sd  mass_n
# 0        28.50  102.11664   3.644901     2.0
# 1        28.50  106.02723  10.670967     2.0
# 2        27.70   88.21495        NaN     1.0
# 3          NaN        NaN        NaN     NaN
# 4          NaN        NaN        NaN     NaN
# ..         ...        ...        ...     ...
# 339      30.00        NaN        NaN     NaN
# 340        NaN        NaN        NaN     NaN
# 341        NaN        NaN        NaN     NaN
# 342        NaN        NaN        NaN     NaN
# 343      29.35   70.53131   4.806064    13.0
#
# [344 rows x 8 columns]

# %%
# Number of turtles per species

num_species = turtles['species'].value_counts()
num_species
# Out:
# species
# Chelonia_mydas            103
# Eretmochelys_imbricata     86
# Dermochelys_coriacea       63
# Caretta_caretta            46
# Lepidochelys_olivacea      43
# Lepidochelys_kempii         2
# Natator_depressus           1
# Name: count, dtype: int64

# %%
turtles['species'] = turtles['species'].replace({
    'Chelonia_mydas': 'green',
    'Eretmochelys_imbricata': 'hawksbill',
    'Dermochelys_coriacea': 'leatherback',
    'Caretta_caretta': 'loggerhead',
    'Lepidochelys_olivacea': 'olive-ridley',
    'Lepidochelys_kempii': 'kemps-ridley',
    'Natator_depressus': 'flatback'
})

turtles
# Out:
#      Unnamed: 0                 name       species  protected_perc  mean_temp  \
# 0            16            Australia    loggerhead        56.25000      28.50
# 1            33               Brazil    loggerhead        50.00000      28.50
# 2            48             Colombia    loggerhead        46.97000      27.70
# 3            50           Cape Verde    loggerhead         0.00000        NaN
# 4            51           Costa Rica    loggerhead       100.00000        NaN
# ..          ...                  ...           ...             ...        ...
# 339         219  Trinidad and Tobago  olive-ridley         0.00000      30.00
# 340         234              Vietnam  olive-ridley        42.86000        NaN
# 341         235              Vanuatu  olive-ridley         0.00000        NaN
# 342         247        French Guiana  olive-ridley        33.33000        NaN
# 343          16            Australia      flatback        72.06471      29.35
#
#      mean_mass    mass_sd  mass_n
# 0    102.11664   3.644901     2.0
# 1    106.02723  10.670967     2.0
# 2     88.21495        NaN     1.0
# 3          NaN        NaN     NaN
# 4          NaN        NaN     NaN
# ..         ...        ...     ...
# 339        NaN        NaN     NaN
# 340        NaN        NaN     NaN
# 341        NaN        NaN     NaN
# 342        NaN        NaN     NaN
# 343   70.53131   4.806064    13.0
#
# [344 rows x 8 columns]

# %%
# Countries with protected areas for sea turtles

countries_turtles = turtles[(turtles['protected_perc'] != 0.00000) & (~turtles['protected_perc'].isna())]
countries_turtles.value_counts()
# Out:
# Unnamed: 0  name              species       protected_perc  mean_temp  mean_mass  mass_sd    mass_n
# 16          Australia         flatback      72.06471        29.35000   70.53131   4.806064   13.0      1
#                               green         59.72000        28.00000   121.38603  6.599796   2.0       1
# 154         Malaysia          green         60.00000        29.12500   108.42966  11.575003  3.0       1
# 160         Nicaragua         hawksbill     62.50000        31.00000   61.04909   0.753600   2.0       1
# 167         Oman              green         50.00000        32.00000   97.22021   7.039119   2.0       1
#                               hawksbill     11.11000        33.66667   50.36215   2.939591   3.0       1
# 176         Puerto Rico       leatherback   4.55000         30.50000   347.26693  9.966033   3.0       1
# 193         Ascension Island  green         100.00000       28.00000   150.91944  16.909256  2.0       1
# 194         Solomon Is.       hawksbill     100.00000       29.00000   63.45920   3.773866   3.0       1
# 196         El Salvador       hawksbill     42.86000        30.00000   62.53437   3.922464   2.0       1
# 209         Seychelles        hawksbill     13.21000        28.26667   66.84528   6.607896   3.0       1
# 214         Thailand          green         66.67000        29.25000   94.95606   14.747953  2.0       1
# 227         United States     green         35.29000        26.66667   102.18662  12.196841  3.0       1
#                               kemps-ridley  16.67000        25.00000   36.84475   6.568674   2.0       1
#                               loggerhead    34.62000        29.48222   101.42847  9.833152   17.0      1
# 231         Venezuela         green         26.32000        28.00000   139.54736  10.088946  2.0       1
# 233         U.S. Virgin Is.   hawksbill     22.73000        30.00000   72.36099   2.934650   2.0       1
# 239         South Africa      green         100.00000       28.80000   135.82059  0.441358   2.0       1
#                               leatherback   100.00000       26.25000   470.10769  14.633648  2.0       1
# 140         Mexico            olive-ridley  11.39000        30.70000   31.76476   1.935776   3.0       1
#                               kemps-ridley  28.00000        29.75000   47.39784   3.396452   4.0       1
#                               hawksbill     61.67000        30.62500   82.26248   1.455155   8.0       1
# 51          Costa Rica        olive-ridley  35.71000        28.37500   32.59001   1.263086   7.0       1
# 16          Australia         hawksbill     21.43000        29.12000   56.93786   7.152980   5.0       1
#                               loggerhead    56.25000        28.50000   102.11664  3.644901   2.0       1
# 33          Brazil            hawksbill     66.67000        28.00000   88.66368   16.935685  3.0       1
#                               loggerhead    50.00000        28.50000   106.02723  10.670967  2.0       1
# 51          Costa Rica        green         33.33000        28.64815   87.85813   25.095540  6.0       1
#                               hawksbill     50.00000        28.80000   62.27503   1.196269   2.0       1
#                               leatherback   56.25000        29.00000   340.51890  24.217923  6.0       1
# 56          Cyprus            green         28.57000        31.93333   86.18125   5.331959   6.0       1
# 140         Mexico            green         41.28000        29.26667   116.76829  33.327067  5.0       1
# 56          Cyprus            loggerhead    20.00000        31.94000   63.01478   2.177194   5.0       1
# 85          Greece            loggerhead    50.00000        28.28571   73.48450   6.202429   7.0       1
# 93          Honduras          olive-ridley  89.47000        27.00000   33.95072   0.000000   2.0       1
# 99          India             olive-ridley  3.77000         27.50000   37.04614   2.422440   3.0       1
# 103         Iran              hawksbill     25.00000        30.77778   42.81100   2.912128   3.0       1
# 111         Japan             loggerhead    51.11000        25.13333   75.38690   6.845069   12.0      1
# 128         Sri Lanka         leatherback   10.34000        29.00000   359.07196  24.832071  2.0       1
# 239         South Africa      loggerhead    100.00000       26.25000   82.44495   3.959241   2.0       1
# Name: count, dtype: int64

# %% [markdown]
# ### Nesting Species

# %%
nests = pd.read_csv('nesting-sites.csv', encoding='latin-1')
nests
# Out:
#      Unnamed: 0              name  all_protected_perc  mean_temp  CC_perc  \
# 0             1             Aruba                 0.0        NaN      0.0
# 1             2       Afghanistan                 NaN        NaN      NaN
# 2             3            Angola                16.7        NaN      NaN
# 3             4          Anguilla                 0.0        NaN      NaN
# 4             5           Albania                 NaN        NaN      NaN
# ..          ...               ...                 ...        ...      ...
# 245         246            Tuvalu                 0.0        NaN      NaN
# 246         247     French Guiana                66.7        NaN      NaN
# 247         248        Guadeloupe                62.3        NaN      NaN
# 248         249        Martinique                10.7        NaN      NaN
# 249         250  Ascension Island               100.0       28.0      NaN
#
#      CM_perc  DC_perc  EI_perc  LK_perc  LO_perc  ND_perc  CC_mass    CM_mass  \
# 0       0.00     0.00     0.00      NaN      NaN      NaN      NaN        NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 2     100.00     0.00      NaN      NaN     0.00      NaN      NaN        NaN
# 3       0.00     0.00     0.00      NaN      NaN      NaN      NaN        NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# ..       ...      ...      ...      ...      ...      ...      ...        ...
# 245     0.00      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 246    50.00    75.00   100.00      NaN    33.33      NaN      NaN        NaN
# 247    57.14    75.86    55.56      NaN      NaN      NaN      NaN        NaN
# 248    66.67    17.65    11.54      NaN      NaN      NaN      NaN        NaN
# 249   100.00      NaN      NaN      NaN      NaN      NaN      NaN  145.16173
#
#      DC_mass  EI_mass  LK_mass  LO_mass  ND_mass
# 0        NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...
# 245      NaN      NaN      NaN      NaN      NaN
# 246      NaN      NaN      NaN      NaN      NaN
# 247      NaN      NaN      NaN      NaN      NaN
# 248      NaN      NaN      NaN      NaN      NaN
# 249      NaN      NaN      NaN      NaN      NaN
#
# [250 rows x 18 columns]

# %%
# Countries with protected areas for sea turtles to lay their eggs

nest_sites = nests[(nests['all_protected_perc'] != 0.0) & (~nests['all_protected_perc'].isna())]
nest_sites
# Out:
#      Unnamed: 0                  name  all_protected_perc  mean_temp  CC_perc  \
# 2             3                Angola                16.7        NaN      NaN
# 7             8  United Arab Emirates                16.7        NaN      NaN
# 10           11        American Samoa                33.3        NaN      NaN
# 14           15     Antigua and Barb.                29.4   29.50000      NaN
# 15           16             Australia                39.5   29.39091    56.25
# ..          ...                   ...                 ...        ...      ...
# 241         242               Mayotte               100.0   27.00000      NaN
# 246         247         French Guiana                66.7        NaN      NaN
# 247         248            Guadeloupe                62.3        NaN      NaN
# 248         249            Martinique                10.7        NaN      NaN
# 249         250      Ascension Island               100.0   28.00000      NaN
#
#      CM_perc  DC_perc  EI_perc  LK_perc  LO_perc  ND_perc    CC_mass  \
# 2     100.00     0.00      NaN      NaN     0.00      NaN        NaN
# 7       0.00      NaN    16.67      NaN      NaN      NaN        NaN
# 10     33.33      NaN      NaN      NaN      NaN      NaN        NaN
# 14     31.03    13.33    30.61      NaN      NaN      NaN        NaN
# 15     59.72    40.00    21.43      NaN    25.00    33.83  102.11664
# ..       ...      ...      ...      ...      ...      ...        ...
# 241   100.00      NaN   100.00      NaN      NaN      NaN        NaN
# 246    50.00    75.00   100.00      NaN    33.33      NaN        NaN
# 247    57.14    75.86    55.56      NaN      NaN      NaN        NaN
# 248    66.67    17.65    11.54      NaN      NaN      NaN        NaN
# 249   100.00      NaN      NaN      NaN      NaN      NaN        NaN
#
#        CM_mass    DC_mass   EI_mass  LK_mass  LO_mass   ND_mass
# 2          NaN        NaN       NaN      NaN      NaN       NaN
# 7          NaN        NaN       NaN      NaN      NaN       NaN
# 10         NaN        NaN       NaN      NaN      NaN       NaN
# 14         NaN        NaN       NaN      NaN      NaN       NaN
# 15   121.38603  471.91282  58.59733      NaN     37.3  72.06471
# ..         ...        ...       ...      ...      ...       ...
# 241  144.57841        NaN       NaN      NaN      NaN       NaN
# 246        NaN        NaN       NaN      NaN      NaN       NaN
# 247        NaN        NaN       NaN      NaN      NaN       NaN
# 248        NaN        NaN       NaN      NaN      NaN       NaN
# 249  145.16173        NaN       NaN      NaN      NaN       NaN
#
# [82 rows x 18 columns]

# %%
# Counting the countries with the highest number of protected sites for species

sorted_countries = nest_sites.sort_values(by=['all_protected_perc'], ascending=False)
sorted_countries
# Out:
#      Unnamed: 0                   name  all_protected_perc  mean_temp  \
# 249         250       Ascension Island               100.0   28.00000
# 241         242                Mayotte               100.0   27.00000
# 169         170           Pitcairn Is.               100.0        NaN
# 100         101  Br. Indian Ocean Ter.               100.0        NaN
# 82           83          Guinea-Bissau               100.0        NaN
# ..          ...                    ...                 ...        ...
# 220         221                 Turkey                 5.6   30.16667
# 98           99                  India                 4.1   27.50000
# 125         126            Saint Lucia                 3.3        NaN
# 231         232     British Virgin Is.                 1.7        NaN
# 234         235                Vanuatu                 1.7        NaN
#
#      CC_perc  CM_perc  DC_perc  EI_perc  LK_perc  LO_perc  ND_perc   CC_mass  \
# 249      NaN   100.00      NaN      NaN      NaN      NaN      NaN       NaN
# 241      NaN   100.00      NaN   100.00      NaN      NaN      NaN       NaN
# 169      NaN   100.00      NaN      NaN      NaN      NaN      NaN       NaN
# 100      NaN      NaN      NaN   100.00      NaN      NaN      NaN       NaN
# 82       NaN   100.00    100.0   100.00      NaN   100.00      NaN       NaN
# ..       ...      ...      ...      ...      ...      ...      ...       ...
# 220     0.00    16.67      NaN      NaN      NaN      NaN      NaN  63.12357
# 98       NaN     2.44      6.9     3.28      NaN     3.77      NaN       NaN
# 125    33.33     0.00      0.0     4.17      NaN      NaN      NaN       NaN
# 231      NaN     0.00      0.0     2.08      NaN      NaN      NaN       NaN
# 234     0.00     1.27      0.0     2.44      NaN     0.00      NaN       NaN
#
#        CM_mass  DC_mass  EI_mass  LK_mass   LO_mass  ND_mass
# 249  145.16173      NaN      NaN      NaN       NaN      NaN
# 241  144.57841      NaN      NaN      NaN       NaN      NaN
# 169        NaN      NaN      NaN      NaN       NaN      NaN
# 100        NaN      NaN      NaN      NaN       NaN      NaN
# 82         NaN      NaN      NaN      NaN       NaN      NaN
# ..         ...      ...      ...      ...       ...      ...
# 220        NaN      NaN      NaN      NaN       NaN      NaN
# 98         NaN      NaN      NaN      NaN  37.04614      NaN
# 125        NaN      NaN      NaN      NaN       NaN      NaN
# 231        NaN      NaN      NaN      NaN       NaN      NaN
# 234        NaN      NaN      NaN      NaN       NaN      NaN
#
# [82 rows x 18 columns]

# %%
# Dot chart showing countries and the percent of protected areas

isolated_data = nest_sites[['name', 'all_protected_perc']]

# Sort values by 'all_protected_perc' in descending order
sorted_data = isolated_data.sort_values(by='all_protected_perc', ascending=False)

# Create a dot chart (scatter plot)
plt.figure(figsize=(10, 6))
plt.scatter(sorted_data['name'], sorted_data['all_protected_perc'], color='blue', marker='o')
plt.xlabel('Name')
plt.ylabel('All Protected Percentage')
plt.title('Dot Chart: All Protected Percentage for Turtle Nesting Sites')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ocean Warming

# %%
ocean = pd.read_csv('ocean-warming.csv')
ocean
# Out:
#    Source (1/24/2023): https://climate.nasa.gov/vital-signs/ocean-warming/   \
# 0                                                YEAR
# 1                                              1957.5
# 2                                              1958.5
# 3                                              1959.5
# 4                                              1960.5
# ..                                                ...
# 60                                             2016.5
# 61                                             2017.5
# 62                                             2018.5
# 63                                             2019.5
# 64                                             2020.5
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0          WO       WOse         NH       NHse         SH       SHse
# 1      -9.303      2.025     -3.149      0.925     -6.153        1.1
# 2      -8.059      2.017     -2.321      0.851     -5.738      1.166
# 3      -8.713      2.036     -2.505      0.824     -6.208      1.212
# 4      -5.479      1.893     -1.587      0.746     -3.892      1.148
# ..        ...        ...        ...        ...        ...        ...
# 60     21.879      0.184      9.654      0.079     12.225      0.104
# 61     22.147       0.19      9.599      0.088     12.548      0.102
# 62     23.294      0.211     10.883      0.085     12.411      0.125
# 63     24.442      0.179     11.444      0.085     12.999      0.094
# 64     25.186      0.183     11.596      0.087     13.591      0.095
#
# [65 rows x 7 columns]

# %% [markdown]
# Notes for interpreting NASA data is on the ocean-warming-about.pdf
#
# Column Name | Description
# Col A: Year
#
# Col B: WO
# Change in World Ocean Heat Content in zettajoules (ZJ) relative to 1957. Each data point represents a five-year (pentadal) running average where the pentadal estimate is provided for the midpoint of the 5-year period. For example, the 1957 value includes OHC estimates from 1955-1959 and the 2020 estimate includes OHC values from 2018-2022.
#
# Col C: WOse
# Standard error (se) for the World Ocean data point in ZJ.
# "±se" is the “uncertainty margin,” or the range from the average within which there is a high probability that the true number resides. For example, when we say the OHC for a particular year is 220 +/- 2 ZJ, the true value for that year has a high probability of being between 218 and 222 zettajoules. The uncertainty margin exists both because of:
# • natural variability (some years, more heat goes into the ocean, other years, less so; some years, more energy goes increasingly deeper in the ocean, and other years, more of it stays closer to the surface)
# • how accurately available instruments are able to measure ocean heat; this has substantially improved over time
# The standard error decreases over time reflecting larger numbers of observation buoys.
#
# Col D: NH
# Annually averaged change in OHC for the Northern Hemisphere in ZJ relative to 1957. Each data point represents a 5-year (pentadal) running average.
#
# Col E: NHse Standard error for the Northern Hemisphere OHC in ZJ.
#
# Col G: SHse Standard error for the Southern Hemisphere OHC in ZJ.
